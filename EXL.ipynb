# %%
import pandas as pd
import numpy as np
import sklearn.model_selection as train_test_split
import seaborn as sns

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
# pd.set_option('display.expand_frame_repr', True)

# %%
df_train=pd.read_csv('train_data.csv')

# %%
df_test=pd.read_csv('test_data.csv')

# %%
df_train['satisfaction']=df_train['var1']/(df_train['var26']+1)**2
# either var 26 or var 29

# %%
df_train['satisfaction'].describe()
# Out:
# count    300000.000000
# mean         50.780032
# std          36.993005
# min           0.004185
# 25%          28.346939
# 50%          42.250000
# 75%          64.673469
# max         263.111111
# Name: satisfaction, dtype: float64

# %%
df_test['satisfaction']=df_test['var1']/(df_test['var26']+1)**2

# %%
df_test['satisfaction'].describe()
# Out:
# count    300000.000000
# mean         50.861667
# std          37.093825
# min           0.004104
# 25%          28.448980
# 50%          42.265306
# 75%          64.593750
# max         263.111111
# Name: satisfaction, dtype: float64

# %%
df_test.drop()
# Out:
#         cust_id  var1  var2  var3  var4  var5  var6  var7  var8    var9  \
# 0        400001  2871     0     0  1925     0     7     0     1  238388
# 1        400002   562     0     0   197     0     3     0     0  136782
# 2        400003  4350     0     1  5664     0     8     1    25  336602
# 3        400004  7580     0     1  6093     0     8     4    31  501694
# 4        400005    58     0     0    53     0     0     0     0   87465
# ...         ...   ...   ...   ...   ...   ...   ...   ...   ...     ...
# 299995   699996  7688     0     1  6161     0     9     3    27  518475
# 299996   699997   330     0     0   499     0     3     0     0  149122
# 299997   699998  1223     0     0  4335     0     5     0     9  277072
# 299998   699999  9078     0     1  7949     3     9    16    66  783744
# 299999   700000  3705     0     0  2982     0     7     0     8  334909
#
#         var10  var11  var12  var13  var14  var15  var16  var21   var22  var23  \
# ...

# %%
df['var27'].mean()*12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f1530c760f1e> in <module>
# ----> 1 df['var27'].mean()*12
#
# NameError: name 'df' is not defined

# %%
df['var26'].sum()

# %%
(df['var29']/df['var26']).describe()

# %%
sns.boxplot((df['var29']/df['var26']).clip(0,0.6))

# %%
(df['var29']/df['var26']).clip(0,0.1).mean()
# Out:
# 0.04226229324113919

# %%
df['var29'].clip(0,0.1).mean()
# Out:
# 0.042139333333333334

# %%
y=df['self_service_platform']

# %%
y.value_counts()
# Out:
# Desktop       184194
# Mobile App     55595
# Mobile Web     48063
# STB            12148
# Name: self_service_platform, dtype: int64

# %%
df['var38'].value_counts()
# Out:
# Agent           65235
# Other           36281
# Self Service    13332
# Name: var38, dtype: int64

# %%
df['var15'].value_counts()
# Out:
# 27      1910
# 165     1873
# 3       1843
# 106     1810
# 13      1695
#         ...
# 1821       1
# 3272       1
# 2884       1
# 2335       1
# 3489       1
# Name: var15, Length: 3658, dtype: int64

# %%
df['var35'].value_counts()
# Out:
# Standard               283150
# CreditCard              10127
# Electronic Transfer      6723
# Name: var35, dtype: int64

# %%
df['var31'].value_counts()
# Out:
# 0     280292
# 1       9885
# 2        946
# 5        914
# 10       884
# 6        877
# 4        876
# 8        855
# 7        855
# 9        839
# 3        822
# 11       443
# 12       421
# 26        88
# 20        88
# 25        87
# 13        82
# 14        80
# 16        79
# 18        79
# 19        79
# 21        75
# 15        73
# 22        72
# 17        69
# 23        68
# 24        65
# 28         5
# 27         2
# Name: var31, dtype: int64

# %%
df.sort_values(by='var27',ascending=False)
# Out:
#         cust_id   var1  var2  var3   var4  var5  var6  var7  var8     var9  \
# 101422   201423  15064     8     3  76567     6     9    48   195  1343945
# 164614   264615  14014    14     2  71035     6     9    74   800  1384505
# 139138   239139  13794    11     4  77164    16     9    69   215  1122481
# 282562   382563  15213    23     2  52568     8     9    35   453  1844155
# 64886    164887  14054     4     2  18731    15     9    63   469  1691798
# ...         ...    ...   ...   ...    ...   ...   ...   ...   ...      ...
# 154093   254094     25     0     0     23     0     0     0     0    25022
# 6313     106314     30     0     0      5     0     0     0     0    31365
# 19450    119451     47     0     0     12     0     0     0     0    35804
# 148387   248388     28     0     0     10     0     0     0     0    12330
# 26144    126145     23     0     0     28     0     0     0     0    38727
#
# ...

# %%
df['var38'].value_counts()
# Out:
# Agent           65235
# Other           36281
# Self Service    13332
# Name: var38, dtype: int64

# %%
df['var21'].describe()
# Out:
# count    300000.000000
# mean         21.047837
# std          19.665769
# min           0.000000
# 25%           8.000000
# 50%          15.000000
# 75%          34.000000
# max         100.000000
# Name: var21, dtype: float64

# %%
### We want to see the factors which can correspond to economic wellbeing
###var6
###var9
###var22
###var27
###var21

# %%
df['var27'].describe()
# Out:
# count    300000.000000
# mean        210.077323
# std        1024.015097
# min           0.000000
# 25%          79.000000
# 50%         136.000000
# 75%         181.000000
# max       21814.000000
# Name: var27, dtype: float64

# %%
sns.countplot(df[df['var12']>1100]['self_service_platform'])

# %%
sns.countplot(df[df['var16']==0]['self_service_platform'])

# %%
sns.countplot(df[df['var33']=='news_channel1'| df['var33']=='news_channel2']['self_service_platform'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\newenv\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# ~\Anaconda3\envs\newenv\lib\site-packages\pandas\core\ops\roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\newenv\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     287             try:
# --> 288                 result = libops.scalar_binop(x, y, op)
# ...

# %%
sns.countplot(df['self_service_platform'])

# %%
df['var30'].value_counts()
# Out:
# .    300000
# Name: var30, dtype: int64

# %%
### How to see number of account disconnects for each social index?
df['var16'].value_counts()
# Out:
# 0    283879
# 1     16121
# Name: var16, dtype: int64

# %%
df['var33'].value_counts()
# Out:
# other                     272972
# news_channel1               8285
# news_channel2               6062
# entertainment_channel1      5563
# entertainment_channel2      4904
# movie_channel1              2214
# Name: var33, dtype: int64
